# %% [markdown]
# # 46-926, Statistical Machine Learning 1: Homework 3
#
# *Author*  : Jordan Giebas <br>
# *Due Date*: Februrary 5th, 2018

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Part (a)
# Load the forward rate data, plot the empirical forward rate data against time.

# %%
import warnings
warnings.filterwarnings(action='ignore')

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#Set the default figure size for the notebook, so they are not all tiny
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv('forward_rates.csv')
df.head()
# Out:
#      time      rate
# 0  0.3699  0.051389
# 1  0.6219  0.050082
# 2  0.8740  0.049707
# 3  1.1260  0.050316
# 4  1.3699  0.056612

# %%
plt.scatter(df.time, df.rate)

# %% [markdown]
# There seems to be a lot of noise around a generally obvious curve. I agree, that linear/quadratic functions wouldn't model this well.

# %% [markdown]
# ### Part (b)
# Fit a smoothing spline to the data using `LinearGAM` as seen in class, and cross-validate for a reasonable $\lambda$. Superimpose a plot of the fit onto the plot above. How well is the fit?

# %%
# !pip3 install pygam
# Out:
# Requirement already satisfied: pygam in /usr/local/lib/python3.6/site-packages
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/site-packages (from pygam)
# Requirement already satisfied: future in /usr/local/lib/python3.6/site-packages (from pygam)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from pygam)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/site-packages (from pygam)
# Requirement already satisfied: python-utils>=2.1.0 in /usr/local/lib/python3.6/site-packages (from progressbar2->pygam)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from python-utils>=2.1.0->progressbar2->pygam)

# %%
from pygam import LinearGAM

gam = LinearGAM().gridsearch(df.time,df.rate,lam = np.logspace(-5, 3, 30))
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# N/A% (0 of 30) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  10% (3 of 30) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  23% (7 of 30) |######                    | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (11 of 30) |#########                | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  50% (15 of 30) |############             | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  60% (18 of 30) |###############          | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  70% (21 of 30) |#################        | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  83% (25 of 30) |####################     | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  93% (28 of 30) |#######################  | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (30 of 30) |#########################| Elapsed Time: 0:00:00 Time: 0:00:00

# %%
cv_lam = gam.lam
print("Cross-validated (default) lambda: ", cv_lam)
# Out:
# Cross-validated (default) lambda:  0.9236708571873865

# %%
gam = LinearGAM(n_splines=len(df.index)+1, lam=cv_lam).fit(df.time,df.rate)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
# Define the domain over which spline will predict
# Many points for smoothness
x_grid = np.linspace(0,30,num=200)

fig, ax = plt.subplots()
ax.plot(x_grid, gam.predict(x_grid), 'r-')
ax.scatter(df.time,df.rate)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline fit $\lambda = CV$");
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %% [markdown]
# The smoothing spline does okay, and captures the variability where present but it is still very wiggly. Below I try a different value of lambda to penalize curvature more.

# %%
gam_2 = LinearGAM(n_splines=len(df.index)+1, lam=1.75).fit(df.time,df.rate)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
fig, ax = plt.subplots()
ax.plot(x_grid, gam_2.predict(x_grid), 'r-')
ax.scatter(df.time,df.rate)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline fit $\lambda = 1.75$");
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %% [markdown]
# Honestly, I think this is better with $\lambda = 1.75$. "Better" in the  sense that it's not as wiggly but it still many of the features.

# %% [markdown]
# ### Part (c)
# Cubic splines are nothing but piecewise cubic functions between various "knots" (datum), with some additional constraints that at each knot they are continuous, and match regarding their first and second derivatives. It's easy to see that integrating cubics over a defined interval is simply, and a closed-form solution exists. Since the first and second derivatives align at each knot, or element in the partition, one can compute the integral between adjacent elements in the partition and then sum them up to acquire the entire integral.

# %% [markdown]
# ## Question 2: Kernel Regression and varying smoothness

# %% [markdown]
# Below is the chunk of code from `adaptivity_starter.py`

# %%
import numpy as np
import pandas as pd
import scipy.stats

### Starter code for Homework 2, problem 7 ###

#Our true mean function: will be sin(x/2) on [0,4*pi] and sin(6*x) on [4*pi,8*pi]
def mu(x):
    
    #Initialize a vector of zeros
    y = np.zeros(len(x))
    
    #Figure out which points are to the left or right of 4*pi
    left_points = (x<=4*np.pi);
    right_points = (x>4*np.pi)
    
    #Assign the appropriate sine values
    y[left_points] = np.sin(x[left_points]/2.0); 
    y[right_points] = np.sin(6*x[right_points])
    
    #Return y
    return(y)


#A function to draw a sample from this curve
def generate_sample(n):

    # Define x
    x = np.random.uniform(low=0, high=8*np.pi, size=n)
    x.sort()

    #Sample the y coordinates as gaussians around mu(x)
    y = mu(x) + np.random.normal(loc=0, scale=0.2, size=n)
    
    #Bind this all together into a pandas data frame
    return(pd.DataFrame({'x':x, 'y':y}))


#We set the seed so that your homeworks will match
scipy.random.seed(7)
#Sample 300 points.  This is your data set!
data = generate_sample(500)

# %%
data.tail()
# Out:
#              x         y
# 495  24.871418 -1.114434
# 496  24.879256 -1.184319
# 497  24.926871 -1.008500
# 498  24.945696 -0.999930
# 499  25.112844  0.158893

# %%
# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (12,8)
fig, ax = plt.subplots()

# Plot true mu(x)
x_grid = np.linspace(start=0, stop = 25.5, num=200)
y_grid = mu(x_grid)
ax.plot(x_grid, mu(x_grid), 'r-')

# Superimpose scatterd data
ax.scatter(data.x,data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline fit $\lambda = 1.75$");

# Put a vertical line to demonstrate where 4\pi is
plt.axvline(x=4*np.pi, color='g')

# %% [markdown]
# The blue dots in the plot above represent the data, and we can see that the true $\mu(x)$ fits this data quite well. The interesting facet of the data is at $x=4\pi$, where the green vertical line occurs. $\forall x \leq 4\pi$, it would be sensible to describe the data using a sinusoid. $\forall x > 4\pi$, it seems like we may be able to describe the data with a sinusoid once again but the frequency with which the crests and troughs oscillate is quite intensified.

# %% [markdown]
# ### Part (b)
#
# Fit a smoothing spline for,<br>
# <ol> <li> $\forall x \leq 4\pi$
#      <li> $\forall x > 4\pi$
#      <li> All the points

# %%
le4pi_data = data[data.x <= 4*np.pi]
gt4pi_data = data[data.x >  4*np.pi]

# %%
len(le4pi_data.index) + len(gt4pi_data.index) == len(data.index)
# Out:
# True

# %%
## Smoothing Spline for x \in [0,4\pi] with suggested lam grid ##

# Fit model
gam_2b_le4pi = LinearGAM().gridsearch(le4pi_data.x, le4pi_data.y, lam = np.logspace(-5, 4, 100))
cv_lam_2b_le4pi = gam_2b_le4pi.lam
gam_2b_le4pi = LinearGAM(n_splines=100, lam=cv_lam_2b_le4pi).fit(le4pi_data.x,le4pi_data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# N/A% (0 of 100) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   4% (4 of 100) |#                        | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   7% (7 of 100) |#                        | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  11% (11 of 100) |##                      | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  15% (15 of 100) |###                     | Elapsed Time: 0:00:00 ETA:  0:00:02/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  19% (19 of 100) |####                    | Elapsed Time: 0:00:00 ETA:  0:00:02/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  23% (23 of 100) |#####                   | Elapsed Time: 0:00:00 ETA:  0:00:02/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (27 of 100) |######                  | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  31% (31 of 100) |#######                 | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  35% (35 of 100) |########                | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  37% (37 of 100) |########                | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  40% (40 of 100) |#########               | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  44% (44 of 100) |##########              | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  47% (47 of 100) |###########             | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  50% (50 of 100) |############            | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (54 of 100) |############            | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  56% (57 of 100) |#############           | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  59% (59 of 100) |##############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  61% (61 of 100) |##############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (63 of 100) |###############         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  65% (65 of 100) |###############         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  68% (68 of 100) |################        | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  73% (73 of 100) |#################       | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  74% (74 of 100) |#################       | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  76% (76 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  79% (79 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  82% (82 of 100) |###################     | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  87% (87 of 100) |####################    | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  92% (92 of 100) |######################  | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  97% (97 of 100) |####################### | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (100 of 100) |#######################| Elapsed Time: 0:00:02 Time: 0:00:02
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
# Plotting
matplotlib.rcParams['figure.figsize'] = (12,8)
x_grid = np.linspace(0,4*np.pi,num=200)
fig, ax = plt.subplots()
ax.plot(x_grid, gam_2b_le4pi.predict(x_grid), 'r-')
ax.scatter(le4pi_data.x,le4pi_data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline, CV lambda, x < 4pi5$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %%
## Smoothing Spline for x \in [4\pi:] with suggested lam grid ##

# Fit model
gam_2b_gt4pi = LinearGAM().gridsearch(gt4pi_data.x, gt4pi_data.y, lam = np.logspace(-5, 4, 100))
cv_lam_2b_gt4pi = gam_2b_gt4pi.lam
gam_2b_gt4pi = LinearGAM(n_splines=100, lam=cv_lam_2b_gt4pi).fit(gt4pi_data.x,gt4pi_data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# N/A% (0 of 100) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   3% (3 of 100) |                         | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   6% (6 of 100) |#                        | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (9 of 100) |##                       | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  12% (12 of 100) |##                      | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  16% (16 of 100) |###                     | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  21% (21 of 100) |#####                   | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  25% (25 of 100) |######                  | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  28% (28 of 100) |######                  | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  31% (31 of 100) |#######                 | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  35% (35 of 100) |########                | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  38% (38 of 100) |#########               | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  42% (42 of 100) |##########              | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (45 of 100) |##########              | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  49% (49 of 100) |###########             | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  52% (52 of 100) |############            | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (54 of 100) |############            | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  56% (57 of 100) |#############           | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  61% (61 of 100) |##############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  64% (64 of 100) |###############         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  68% (68 of 100) |################        | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  71% (71 of 100) |#################       | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  75% (75 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  79% (79 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  83% (83 of 100) |###################     | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  87% (87 of 100) |####################    | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (90 of 100) |#####################   | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  93% (93 of 100) |######################  | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  97% (97 of 100) |####################### | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (100 of 100) |#######################| Elapsed Time: 0:00:01 Time: 0:00:01
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
x_grid = np.linspace(4*np.pi, 25.5,num=200)
fig, ax = plt.subplots()
ax.plot(x_grid, gam_2b_gt4pi.predict(x_grid), 'r-')
ax.scatter(gt4pi_data.x,gt4pi_data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline, CV lambda, x >= 4pi5$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %%
## Smoothing Spline for x with suggested lam grid ##

# Fit model
gam_2b_alldata = LinearGAM().gridsearch(data.x, data.y, lam = np.logspace(-5, 4, 100))
cv_lam_2b_alldata = gam_2b_alldata.lam
gam_2b_alldata = LinearGAM(n_splines=100, lam=cv_lam_2b_alldata).fit(data.x,data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# N/A% (0 of 100) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   3% (3 of 100) |                         | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   7% (7 of 100) |#                        | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  11% (11 of 100) |##                      | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  16% (16 of 100) |###                     | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  21% (21 of 100) |#####                   | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  25% (25 of 100) |######                  | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  30% (30 of 100) |#######                 | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  33% (33 of 100) |#######                 | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (36 of 100) |########                | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  40% (40 of 100) |#########               | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  44% (44 of 100) |##########              | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  47% (47 of 100) |###########             | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  51% (51 of 100) |############            | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  55% (55 of 100) |#############           | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  59% (59 of 100) |##############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (63 of 100) |###############         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  66% (66 of 100) |###############         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  70% (70 of 100) |################        | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  73% (73 of 100) |#################       | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  76% (76 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  79% (79 of 100) |##################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  82% (82 of 100) |###################     | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  85% (85 of 100) |####################    | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  88% (88 of 100) |#####################   | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  92% (92 of 100) |######################  | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  97% (97 of 100) |####################### | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (100 of 100) |#######################| Elapsed Time: 0:00:01 Time: 0:00:01
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
x_grid = np.linspace(0, 25.5,num=400)
fig, ax = plt.subplots()
ax.plot(x_grid, gam_2b_alldata.predict(x_grid), 'r-')
ax.scatter(data.x,data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline, CV lambda, x >= 4pi5$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %% [markdown]
# The cell below prints out each of the Cross-Validated (optimal) lambdas

# %%
print("CV_lambda_le4pi: ", cv_lam_2b_le4pi)
print("CV_lambda_gt4pi: ", cv_lam_2b_gt4pi)
print("CV_lambda_data : ", cv_lam_2b_alldata)
# Out:
# CV_lambda_le4pi:  23.10129700083163
# CV_lambda_gt4pi:  0.0003511191734215131
# CV_lambda_data :  8.111308307896872

# %% [markdown]
# The output of the above cell is sensible. For $x \in [0,4\pi]$, $\lambda_{le4\pi}$ is very large. This is because we are penalizing for extreme curvature, which is sensible since this piece of the graph doesn't suggest much curvature. On the contrary, for $x \in [4\pi,25.5]$, $\lambda_{gt4\pi}$ is very small. This again is sensible since the graph has a lot of curvature and we should therefore not penalize for a lot of curvature. <br>
#
# Lastly, the $\lambda{CV}$ for the whole domain of $x$ is in between these values. In order to compensate for the lack of curvature in the first partition to the second, or vice-versas to adjust for the difference in curvature from the second partition to the first, the spline chooses a lambda in between the extreme cases we saw in each of the partitions separately. <br>
#
# This is a limitation of the smoothing splines: abrupt changes of curvature at any given knot will result in a case as the above due to the constraints in continuity, differentiability, and curvature at each knot.

# %% [markdown]
# ### Part (c)
#
# Using the above lambdas, refit the smoothing spline on the entire data set and superimpose the plot with the true mean $\mu(x)$ and the datum.

# %%
# Case I: Lambda equals CV_lambda_le4pi/2 (23.10129700083163/2)

gam_2c_1 = LinearGAM(n_splines=100, lam=cv_lam_2b_le4pi/2.0).fit(data.x,data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
x_grid = np.linspace(0, 25.5,num=400)
fig, ax = plt.subplots()
ax.plot(x_grid, mu(x_grid), 'k-')
ax.plot(x_grid, gam_2c_1.predict(x_grid), 'r-')
ax.scatter(data.x,data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline all data, first partition lambda/2.0$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %%
# Case II: Lambda equals CV_lambda_gt4pi/2 (0.0003511191734215131/2)
gam_2c_2 = LinearGAM(n_splines=100, lam=cv_lam_2b_gt4pi/2.0).fit(data.x,data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
x_grid = np.linspace(0, 25.0,num=400)
fig, ax = plt.subplots()
ax.plot(x_grid, mu(x_grid), 'k-')
ax.plot(x_grid, gam_2c_2.predict(x_grid), 'r-')
ax.scatter(data.x,data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline all data, second partition lambda/2.0$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %%
# Case III: Lambda equals CV_lambda_gt4pi/2 (0.0003511191734215131/2)
gam_2c_3 = LinearGAM(n_splines=100, lam=cv_lam_2b_alldata).fit(data.x,data.y)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
x_grid = np.linspace(0, 25.0,num=400)
fig, ax = plt.subplots()
ax.plot(x_grid, mu(x_grid), 'k-')
ax.plot(x_grid, gam_2c_3.predict(x_grid), 'r-')
ax.scatter(data.x,data.y)
ax.set(xlabel = r"$x$",
       ylabel = r"$y$",
       title = r"Smoothing spline all data, all data lambda/2.0$");
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:165: UserWarning: Expected 2D input data array, but found 1D. Expanding to 2D.
#   warnings.warn(msg)

# %% [markdown]
# In each of the three cases, I have already somewhat discussed the issue above. <br>
# <ul>
# <li>When the $\lambda_{CV}$ is very big, we are penalizing a lot for curvature. So we see that the first partition of the graph is well fit, but we don't capture the chaotic nature of the second partiiton at all. We can see that we are far from the true mean.
# <li>When the $\lambda_{CV}$ is very small, we are not penalizing a lot for curvature. So we see that while we genearlly fit the first partition of the graph, we are not nearly smooth enough as the data suggests. This being said, we capture the essence of the second partition very well since we are more flexible for curvature. Over the first partition, we generally deviate quite a big from the mean, but over the second we right in line.
# <li>When the $\lambda_{CV}$ is in between these two cases, we see that we are compromising to some degree. We generally are aligned with the mean over the first partition (minus some small deviations), but we do not model the mean/datum well at all over the second partiiton because we are underestimating.

# %% [markdown]
# ## Question 3

# %%
train_df = pd.read_csv('bike_train.csv')
test_df = pd.read_csv('bike_test.csv')

# %%
train_df.head()
# Out:
#    dayofyear  dayofweek  workday  weathertype      temp  humidity  windspeed  \
# 0          0          6        0            2  0.344167  0.805833   0.160446
# 1          1          0        0            2  0.363478  0.696087   0.248539
# 2          2          1        1            1  0.196364  0.437273   0.248309
# 3          3          2        1            1  0.200000  0.590435   0.160296
# 4          4          3        1            1  0.226957  0.436957   0.186900
#
#    rentals
# 0      985
# 1      801
# 2     1349
# 3     1562
# 4     1600

# %%
set(np.array(train_df.weathertype).tolist())
# Out:
# {1, 2, 3}

# %% [markdown]
# I think that the weather type only takes on 4 values in the training set....

# %% [markdown]
# ### Part (a)
# Fit a linear model using each of the features, then make predictions on the test data.

# %%
# Separate features and targets in both test/train data

# Training features, target
y_train = train_df.rentals
X_train = train_df.drop(['rentals'], axis=1)

# Test features, target
y_test = test_df.rentals
X_test = test_df.drop(['rentals'], axis=1)

# %%
# import sklearn linear regression modules
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Fit the linear model
lm = LinearRegression()
lm.fit(X_train, y_train)

# Make the prediction, alter by 1.6 for increased growth
altered_pred_y = 1.6*lm.predict(X_test)

# Get mean squared error
mse = mean_squared_error(altered_pred_y,y_test)
print("MSE: ", mse)
# Out:
# MSE:  1295159.39451

# %% [markdown]
# The MSE seems to be astronomical... is this actually correct?

# %% [markdown]
# ### Part (b)
# Fit the additive model in pygam with LinearGAM, make altered predictions, and compare the MSE's.

# %%
from pygam import LinearGAM

gam = LinearGAM().gridsearch(X_train,y_train,lam = np.logspace(-5, 3, 30))
# Out:
# N/A% (0 of 30) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   3% (1 of 30) |                          | Elapsed Time: 0:00:00 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   6% (2 of 30) |#                         | Elapsed Time: 0:00:00 ETA:  0:00:02/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  10% (3 of 30) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  13% (4 of 30) |###                       | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  16% (5 of 30) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  20% (6 of 30) |#####                     | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  23% (7 of 30) |######                    | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  26% (8 of 30) |######                    | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  30% (9 of 30) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  33% (10 of 30) |########                 | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (11 of 30) |#########                | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  40% (12 of 30) |##########               | Elapsed Time: 0:00:00 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  43% (13 of 30) |##########               | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  46% (14 of 30) |###########              | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  50% (15 of 30) |############             | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  53% (16 of 30) |#############            | Elapsed Time: 0:00:01 ETA:  0:00:01/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  56% (17 of 30) |##############           | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  60% (18 of 30) |###############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (19 of 30) |###############          | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  66% (20 of 30) |################         | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  70% (21 of 30) |#################        | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  73% (22 of 30) |##################       | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  76% (23 of 30) |###################      | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  80% (24 of 30) |####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  83% (25 of 30) |####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  86% (26 of 30) |#####################    | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (27 of 30) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  93% (28 of 30) |#######################  | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  96% (29 of 30) |######################## | Elapsed Time: 0:00:02 ETA:  0:00:00/usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (30 of 30) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02

# %%
cv_lam = gam.lam
gam = LinearGAM(n_splines=len(X_train.index)+1, lam=cv_lam).fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 1
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/pygam.py:1187: UserWarning: detected catergorical data for feature 2
#   self._validate_data_dep_params(X)
# /usr/local/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)

# %%
y_pred_gam = 1.6*gam.predict(X_test)

# %%
mse_gam = mean_squared_error(y_pred_gam, y_test)
print("MSE using GAM: ", mse_gam)
# Out:
# MSE using GAM:  1100002.45604

# %% [markdown]
# So we have a seen reduction in MSE, but the MSE is still quite big........

# %% [markdown]
# ### Part (c)
# Plotting the function for each of the smooth covariates (i.e., temp, humidity, and windspeed, since all the others are binary). <br>
# ** Do we need to plot these for test or train data?? **

# %%
plt.xlabel('Windspeed')
plt.ylabel('Number rentals')
plt.title('Rentals vs. Windspeed')
plt.scatter(X_test.windspeed, y_test)

# %%
plt.xlabel('Humidity')
plt.ylabel('Number rentals')
plt.title('Rentals vs. Humidity')
plt.scatter(X_test.humidity, y_test)

# %%
plt.xlabel('Temperature')
plt.ylabel('Number rentals')
plt.title('Rentals vs. Temperature')
plt.scatter(X_test.temp, y_test)

# %% [markdown]
# The above three plots suggest that temperature is the covariate that best resembles a linear function. Both windspeed and humidity follow no sort of linear trend. Truthfully, I see no trend at all let alone one that a linear function would miss. <br>
# ** THIS IS MUCH DIFFERENT ON TEST DATA THAN TRAIN DATA, THE ABOVE ANALYSIS REGARDS THE TRAIN DATA BUT THE THREE PICTURES NOW REVEAL THE TEST DATA **

# %% [markdown]
# ### Part (d)
# Let's use a new (idealized) loss function. The function below was provided, but we examine the linear model and the spline now to compare the errors.

# %%
# Function provided by Prof. G'sell
def real_loss(true, guess):
    return ( np.mean(np.where(true>guess, 5*(true-guess), guess-true)) )


print("Linear real loss: ", real_loss(y_test, altered_pred_y))
print("Spline real loss: ", real_loss(y_test, y_pred_gam))
# Out:
# Linear real loss:  2412.83028509
# Spline real loss:  2190.25813462

# %% [markdown]
# From the above, we observe that we'd prefer to use the additive model. Is this a coincidence, or did you construct this loss function to ensure we'd prefer the spline over the linear model Prof. G'sell?

# %% [markdown]
# ### Part (e)

# %% [markdown]
# Moving away from averages due to asymmetric loss functions.

# %%
# Define the vector of residuals
resid_gam = y_test - y_pred_gam
resid_lin = y_test - altered_pred_y

# Obtain the quantiles
gam_q = np.percentile(resid_gam, 5/6.0)
lin_q = np.percentile(resid_lin, 5/6.0)

# Update the estimates by the appropriate quantiles
y_pred_gam     += gam_q
altered_pred_y += lin_q

# Obtain the real loss for both, relative to target y_test
print("Linear adjusted real loss: ", real_loss(y_test, altered_pred_y))
print("Spline adjusted real loss: ", real_loss(y_test, y_pred_gam))
# Out:
# Linear adjusted real loss:  16779.6651304
# Spline adjusted real loss:  14967.556622

# %% [markdown]
# I'm unsure how this helped exactly....

# %% [markdown]
# ## Question 4

# %% [markdown]
# Maybe will write up in latex, maybe will turn in jpeg... not sure yet
